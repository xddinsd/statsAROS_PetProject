# %%
from cohort_Statistics import cohort_Statistics

# %%
# cohort_Stat(9, 21, 'Physics')

# result, histPlotFig, mainPlotFig = cohort_Statistics.cohort_Stat(9, 22, 'Economics')
# histPlotFig.show()
# mainPlotFig.show()
resultList, result, histPlotFig, mainPlotFig = cohort_Statistics.cohort_Stat(9, 21, 'Physics')
for line in resultList:
    print(line)
# result, histPlotFig, mainPlotFig = cohort_Statistics.cohort_Stat(9, 22, 'Math')
# Out:
# Physics | PRIZES a year before (BLACK) vs OTHERS (BLUE) in 22-23
# Mean Prizes is 46.36600000000001 | Mean Others is 47.330000000000005
#     H_0: Actually MeanP == MeanO
#     H_1: Not equal
#
# Check criteria for a T-Test:
#      Passed! | Levene | Shapiro-Wilk
#
# Performing a T-Test:
#     p_value is 0.89364 |
# Can't reject the H_0
#
# Performing a KS-Test:
#     p_value is 0.70167 |
# Can't reject the H_0
#
# Physics | 22-23 | (MeanOfPrizes > MeanOfOthers) is Not defined

# %%
#

# %%
subjectNames = ["Economics", "Math", "Physics"]
start_years = [12, 22, 23] # 21-22, 22-23, 23-24
grade_start = [9, 10]
